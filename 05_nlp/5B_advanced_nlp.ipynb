# %% [markdown]
# # (5B) NLP Cookbook, part 2: Advanced NLP
#
# In this second installment of NLP, let's look at some of the more advanced questions:
#
# * Detect proper nouns of places and people?
# * Identify noun phrases? ("natural language processing", "education department", etc)
# * Sentiment analysis? (estimating positive/negative sentiment of text)
# * Describe sentence syntax? (clauses, subject-object and other "dependencies", etc)s

# %% [markdown]
# -----
#
# ## How can I identify places and people?

# %%
# Manzanar loves Named Entity Recognition

manzanar = """Despite everything, every sports event, concert, and whatnot was happening at the same time. L.A.
marathoners slouched by the droves across the finish line at the Coliseum. At the Rose Bowl: UCLA versus
USC; the Bruin mascot had been carried off the field with heat stroke, and the Trojan horse was tied up
after throwing its sweaty rider. The Clippers were attempting a comeback in overtime at the Sports Arena.
It was the end of the seventhinning stretch, and Nomo fans at Chavez Ravine hunkered down with their cold
beers and Dodger dogs. Scottie Pippen fouled Shaq who sank a free throw for the Lakers at the Forum in the
last seconds. The Trekkie convention warped into five at the L.A. Convention Center. Bud Girls paraded
between boxing matches at the Olympic Auditorium. Plácido Domingo belted Rossini at the Dorothy Chandler
under the improbable abstract/minimal/baroque direction of Peter Sellers. At the Shrine, executive
producer Richard Sakai accepted an Oscar for the movie version of The Simpsons. The helicopter landed for
the 944th time on the set of Miss Saigon at the Ahmanson, and Beauty smacked the Beast at the Shubert.
Chinese housewives went for the big stakes in pai gow in the Asian room at the Bicycle Club. Live-laughter
sitcom audiences and boisterous crowds for the daytime and nighttime talks filled every available studio
in Hollywood and Burbank. Thousands of fans melted away with Julio Iglesias at the Universal Amphitheater."""

# %%
# do some imports
import os
import nltk
import pandas as pd
pd.set_option('display.max_colwidth', 0)

# %% [markdown]
# ### (1) NLTK

# %%
# let's make a function for this
def ner_nltk(string):
    # clean string
    string = string.strip().replace('\n',' ')
    
    # sentence tokenize the string
    sentences = nltk.sent_tokenize(string)
    
    # set empty list for output
    output_list = []
    
    # loop over each sentence
    sent_num = 0
    for sent in sentences:
        # add 1
        sent_num+=1
        added_sent_already = False
        
        # we need to get the words
        sent_words = nltk.word_tokenize(sent)
        
        # parts of speech
        sent_pos = nltk.pos_tag(sent_words)
        
        # then "chunk":
        chunks = nltk.ne_chunk(sent_pos)
        
        # loop over chunks...
        for chunk in chunks:
            #print(chunk)
            
            # if the chunk has a 'label' attribute (is a named entity)
            if hasattr(chunk,'label'):
                
                # get the label
                label = chunk.label()
                
                # print
                #print(label,list(chunk))
                
                # get the words
                chunk_words = []
                for word,pos in chunk:
                    chunk_words.append(word)
                
                # make a string version
                chunk_words_str = ' '.join(chunk_words)
                
                # make a result dictionary
                result_dict = {}
                
                # add NER info
                result_dict['type'] = label
                result_dict['entity'] = chunk_words_str
                
                # add sent info
                result_dict['_sent_num'] = sent_num
                
                # add a string of the sentence, but only once per sentence
                if not added_sent_already:
                    result_dict['_sent'] = sent
                    added_sent_already = True
                else:
                    result_dict['_sent'] = ''
                
                # add result dictionary to output list
                output_list.append(result_dict)
    
    # return output
    #output_df=pd.DataFrame(output_list)
    #return output_df
    return output_list

# %%
nltk_ner_ld = ner_nltk("""Ryan Heuser cannot wait until he graduates from Stanford University.
He will take up position as Head Engineer of NASA's secret "Send Literary Critics to Mars" mission.""")
nltk_ner_ld[0]
# Out:
# {'type': 'PERSON',
#  'entity': 'Ryan',
#  '_sent_num': 1,
#  '_sent': 'Ryan Heuser cannot wait until he graduates from Stanford University.'}

# %%
nltk_ner_df = pd.DataFrame(nltk_ner_ld)
nltk_ner_df
# Out:
#                                                                                                  _sent  \
# 0  Ryan Heuser cannot wait until he graduates from Stanford University.
# 1
# 2
# 3  He will take up position as Head Engineer of NASA's secret "Send Literary Critics to Mars" mission.
# 4
# 5
#
#    _sent_num               entity          type
# 0  1          Ryan                 PERSON
# 1  1          Heuser               PERSON
# 2  1          Stanford University  ORGANIZATION
# 3  2          Head Engineer        PERSON
# 4  2          NASA                 ORGANIZATION
# 5  2          Mars                 PERSON

# %%
nltk_ner_ld = ner_nltk(manzanar)
nltk_ner_ld[0]
# Out:
# {'type': 'GPE',
#  'entity': 'Coliseum',
#  '_sent_num': 2,
#  '_sent': 'L.A. marathoners slouched by the droves across the finish line at the Coliseum.'}

# %%
nltk_ner_df = pd.DataFrame(nltk_ner_ld)
nltk_ner_df
# Out:
#                                                                                                                                                                      _sent  \
# 0   L.A. marathoners slouched by the droves across the finish line at the Coliseum.
# 1   At the Rose Bowl: UCLA versus USC; the Bruin mascot had been carried off the field with heat stroke, and the Trojan horse was tied up after throwing its sweaty rider.
# 2
# 3
# 4
# 5   The Clippers were attempting a comeback in overtime at the Sports Arena.
# 6
# 7   It was the end of the seventhinning stretch, and Nomo fans at Chavez Ravine hunkered down with their cold beers and Dodger dogs.
# 8
# 9
# 10  Scottie Pippen fouled Shaq who sank a free throw for the Lakers at the Forum in the last seconds.
# 11
# 12
# 13  The Trekkie convention warped into five at the L.A. Convention Center.
# 14
# 15  Bud Girls paraded between boxing matches at the Olympic Auditorium.
# 16
# 17  Plácido Domingo belted Rossini at the Dorothy Chandler under the improbable abstract/minimal/baroque direction of Peter Sellers.
# 18
# 19
# 20
# 21
# 22  At the Shrine, executive producer Richard Sakai accepted an Oscar for the movie version of The Simpsons.
# 23
# 24
# 25  The helicopter landed for the 944th time on the set of Miss Saigon at the Ahmanson, and Beauty smacked the Beast at the Shubert.
# 26
# 27
# 28
# 29  Chinese housewives went for the big stakes in pai gow in the Asian room at the Bicycle Club.
# 30
# 31
# 32  Live-laughter sitcom audiences and boisterous crowds for the daytime and nighttime talks filled every available studio in Hollywood and Burbank.
# 33
# 34  Thousands of fans melted away with Julio Iglesias at the Universal Amphitheater.
# 35
#
#     _sent_num                  entity          type
# 0   2          Coliseum                GPE
# 1   3          Rose                    ORGANIZATION
# 2   3          USC                     ORGANIZATION
# 3   3          Bruin                   GPE
# 4   3          Trojan                  GPE
# 5   4          Clippers                ORGANIZATION
# 6   4          Sports Arena            ORGANIZATION
# 7   5          Nomo                    ORGANIZATION
# 8   5          Chavez Ravine           ORGANIZATION
# 9   5          Dodger                  GPE
# 10  6          Scottie                 PERSON
# 11  6          Pippen                  PERSON
# 12  6          Shaq                    PERSON
# 13  7          Trekkie                 ORGANIZATION
# 14  7          L.A. Convention Center  ORGANIZATION
# 15  8          Bud                     PERSON
# 16  8          Girls                   PERSON
# 17  9          Plácido                 PERSON
# 18  9          Domingo                 PERSON
# 19  9          Rossini                 PERSON
# 20  9          Dorothy                 ORGANIZATION
# 21  9          Peter Sellers           PERSON
# 22  10         Shrine                  GPE
# 23  10         Richard Sakai           PERSON
# 24  10         Simpsons                ORGANIZATION
# 25  11         Miss Saigon             ORGANIZATION
# 26  11         Ahmanson                ORGANIZATION
# 27  11         Beauty                  PERSON
# 28  11         Shubert                 ORGANIZATION
# 29  12         Chinese                 GPE
# 30  12         Asian                   GPE
# 31  12         Bicycle Club            ORGANIZATION
# 32  13         Hollywood               GPE
# 33  13         Burbank                 GPE
# 34  14         Julio Iglesias          PERSON
# 35  14         Universal Amphitheater  ORGANIZATION

# %%
# Save this data!
nltk_ner_df.to_excel('data.ner_nltk.xls')

# %% [markdown]
# ### (3) Polyglot (for non-English, non-French, non-German text)
#
# [Polyglot](https://polyglot.readthedocs.io/) is a really cool package, built on top of TextBlob, which supports up to 140 different languages depending on the NLP task. This increase in linguistic range comes at a cost of accuracy, however. The tools was trained using Wikipedia as a Rosetta Stone, calibrating languages' models against each other by using the "same" articles in those languages. The other costs of using Polyglot: the documentation isn't that great, and it doesn't seem to be actively updated.
#
# *Installation is also kind of a pain in the neck.* I recommend installing this only if you are planning to work with non-English, non-French, non-German text. To do so, paste the following into Terminal:
#
#     conda install -c conda-forge pyicu
#     pip install pycld2
#     pip install morfessor
#     pip install polyglot
#     polyglot download LANG:en   # for english
#     polyglot download LANG:es   # for spanish (optional)
#     polyglot download LANG:xx   # where xx is the two-letter language code
#
# See [the website](https://polyglot.readthedocs.io/) for more details.

# %%
def ner_polyglot(string):
    # let's try this...
    try:
        # to use polyglot, import its "Text" object:
        from polyglot.text import Text
    except ImportError:
        print('Polyglot not installed! To do so, follow the instructions above.')
        return
    # from here on we can assume that polyglot is imported
    
    # wrap that Text object around any string
    pg_text = Text(string)

    # make an output list
    output_list = []
    
    # get the entities
    entities = pg_text.entities
    # loop over sentences
    sent_num = 0
    for sent in pg_text.sentences:
        sent_num+=1

        # loop over the entities
        added_sent_already = False
        for ent in sent.entities:
            # get the type
            ent_type = ent.tag

            # get the words
            ent_words = list(ent)

            # bogus if the first letter of the first word is not alphabetic (not punctuation)
            if not ent_words[0][0].isalpha(): continue

            # make a string version
            ent_words_str = ' '.join(ent_words)

            # make a results dict
            result_dict = {}
            result_dict['_sent_num'] = sent_num
            if not added_sent_already:
                result_dict['_sent'] = str(sent)
                added_sent_already = True
            else:
                result_dict['_sent'] = ''
            
            result_dict['type']=ent_type
            result_dict['entity']=ent_words_str

            # add to output
            output_list.append(result_dict)
        
    return output_list

# %%
ner_polyglot("""Ryan Heuser cannot wait until he graduates from Stanford University.
He will take up position as Head Engineer of NASA's secret "Send Literary Critics to Mars" mission.""")
# Out:
# [{'_sent_num': 1,
#   '_sent': 'Ryan Heuser cannot wait until he graduates from Stanford University.',
#   'type': 'I-PER',
#   'entity': 'Ryan Heuser'},
#  {'_sent_num': 1,
#   '_sent': '',
#   'type': 'I-ORG',
#   'entity': 'Stanford University'}]

# %%
# Run on Manzanar's paragraph
pd.DataFrame(ner_polyglot(manzanar))
# Out:
#                                                                                                         _sent  \
# 0   marathoners slouched by the droves across the finish line at the Coliseum.
# 1   At the Rose Bowl: UCLA versus
# 2
# 3   USC; the Bruin mascot had been carried off the field with heat stroke, and the Trojan horse was tied up
# 4
# 5   The Clippers were attempting a comeback in overtime at the Sports Arena.
# 6
# 7   It was the end of the seventhinning stretch, and Nomo fans at Chavez Ravine hunkered down with their cold
# 8   Scottie Pippen fouled Shaq who sank a free throw for the Lakers at the Forum in the
# 9
# 10
# 11  Bud Girls paraded
# 12  Plácido Domingo belted Rossini at the Dorothy Chandler
# 13
# 14
# 15  under the improbable abstract/minimal/baroque direction of Peter Sellers.
# 16  producer Richard Sakai accepted an Oscar for the movie version of The Simpsons.
# 17  the 944th time on the set of Miss Saigon at the Ahmanson, and Beauty smacked the Beast at the Shubert.
# 18
# 19
# 20  Chinese housewives went for the big stakes in pai gow in the Asian room at the Bicycle Club.
# 21
# 22  in Hollywood and Burbank.
# 23
# 24  Thousands of fans melted away with Julio Iglesias at the Universal Amphitheater.
# 25
#
#     _sent_num            entity   type
# 0   3          Coliseum          I-ORG
# 1   4          Rose Bowl         I-ORG
# 2   4          UCLA              I-ORG
# 3   5          USC               I-ORG
# 4   5          Bruin             I-ORG
# 5   7          Clippers          I-ORG
# 6   7          Sports Arena      I-ORG
# 7   8          Chavez            I-PER
# 8   10         Scottie Pippen    I-PER
# 9   10         Shaq              I-PER
# 10  10         Lakers            I-ORG
# 11  14         Bud Girls         I-PER
# 12  16         Plácido Domingo   I-PER
# 13  16         Rossini           I-PER
# 14  16         Dorothy Chandler  I-PER
# 15  17         Peter Sellers     I-PER
# 16  19         Richard Sakai     I-PER
# 17  21         Miss Saigon       I-ORG
# 18  21         Ahmanson          I-ORG
# 19  21         Shubert           I-ORG
# 20  22         pai gow           I-PER
# 21  22         Bicycle Club      I-ORG
# 22  25         Hollywood         I-LOC
# 23  25         Burbank           I-LOC
# 24  26         Julio Iglesias    I-PER
# 25  26         Universal         I-ORG

# %% [markdown]
# ### (4) Spacy
#
# [Spacy](http://spacy.io) is industrial-strength NLP. It's the fastest, most powerful, and most accurate. It can also work on [several languages besides English](https://spacy.io/models). But it's also kinda ugly and confusing to use. I recommend using this only if you are working on hundreds of texts and feel extremely comfortable with all the things we've been doing so far.
#
# To install:
#
#     pip install spacy
#     python -m spacy download en_core_web_sm
#
# Here's an NER implementation.

# %%
def ner_spacy(string):
    try:
        # import spacy
        import spacy
    except ImportError:
        print("spacy not installed. Please follow directions above.")
        return

    # clean string
    string = string.strip().replace('\n',' ').replace("’","'").replace("‘","'")
    
    # load its default English model
    nlp = spacy.load("en_core_web_sm")

    # create a spacy text object
    doc = nlp(string)
    
    # make an output list
    output_list = []

    # loop over sentences
    sent_num=0
    for sent in doc.sents:
        sent_num+=1
        added_sent_already = False

        # loop over sentence's entities
        for ent in sent.ents:
            
            # make a result dict
            result_dict = {}
            
            # set sentence number
            result_dict['_sent_num'] = sent_num
            
            # store text too
            if not added_sent_already:
                result_dict['_sent'] = sent.text
                added_sent_already = True
            else:
                result_dict['_sent'] = ''
            
            # get type
            result_dict['type'] = ent.label_
            
            # get entity
            result_dict['entity'] = ent.text
            
            # get start char
            result_dict['star_char'] = ent.start_char
            
            # get end char
            result_dict['star_char'] = ent.end_char
            
            # add result_dict to output_list
            output_list.append(result_dict)
            
    # return output
    return output_list

# %%
pd.DataFrame(ner_spacy("""Ryan Heuser cannot wait until he graduates from Stanford University.
He will take up position as Head Engineer of NASA's secret "Send Literary Critics to Mars" mission."""))
# Out:
#                                                                                                  _sent  \
# 0  Ryan Heuser cannot wait until he graduates from Stanford University.
# 1
# 2  He will take up position as Head Engineer of NASA's secret "Send Literary Critics to Mars" mission.
# 3
# 4
#
#    _sent_num                         entity  star_char         type
# 0  1          Ryan Heuser                    11         PERSON
# 1  1          Stanford University            67         ORG
# 2  2          Engineer                       110        PERSON
# 3  2          NASA                           118        ORG
# 4  2          Send Literary Critics to Mars  158        WORK_OF_ART

# %%
spacy_ner_ld = ner_spacy(manzanar)
spacy_ner_ld[0]
# Out:
# {'_sent_num': 2,
#  '_sent': 'L.A. marathoners slouched by the droves across the finish line at the Coliseum.',
#  'type': 'GPE',
#  'entity': 'L.A.',
#  'star_char': 97}

# %%
spacy_ner_df = pd.DataFrame(spacy_ner_ld)
spacy_ner_df
# Out:
#                                                                                                                                                                      _sent  \
# 0   L.A. marathoners slouched by the droves across the finish line at the Coliseum.
# 1
# 2   At the Rose Bowl: UCLA versus USC; the Bruin mascot had been carried off the field with heat stroke, and the Trojan horse was tied up after throwing its sweaty rider.
# 3
# 4
# 5
# 6   The Clippers were attempting a comeback in overtime at the Sports Arena.
# 7
# 8   It was the end of the seventhinning stretch, and Nomo fans at Chavez Ravine hunkered down with their cold beers and Dodger dogs.
# 9
# 10
# 11  Scottie Pippen fouled Shaq who sank a free throw for the Lakers at the Forum in the last seconds.
# 12
# 13  The Trekkie convention warped into five at the L.A. Convention Center.
# 14
# 15
# 16  Bud Girls paraded between boxing matches at the Olympic Auditorium.
# 17
# 18  Plácido Domingo belted Rossini at the Dorothy Chandler under the improbable abstract/minimal/baroque direction of Peter Sellers.
# 19
# 20
# 21
# 22  At the Shrine, executive producer Richard Sakai accepted an Oscar for the movie version of The Simpsons.
# 23
# 24
# 25
# 26  The helicopter landed for the 944th time on the set of Miss Saigon at the Ahmanson, and Beauty smacked the Beast at the Shubert.
# 27
# 28
# 29
# 30  Chinese housewives went for the big stakes in pai gow in the Asian room at the Bicycle Club.
# 31
# 32
# 33  Live-laughter sitcom audiences and boisterous crowds for the daytime and nighttime talks filled every available studio in Hollywood and Burbank.
# 34
# 35  Thousands of fans melted away with Julio Iglesias at the Universal Amphitheater.
# 36
#
#     _sent_num                      entity  star_char         type
# 0   2          L.A.                        97         GPE
# 1   2          Coliseum                    171        PERSON
# 2   3          the Rose Bowl               189        FAC
# 3   3          USC                         206        ORG
# 4   3          Bruin                       217        NORP
# 5   3          Trojan                      288        GPE
# 6   4          Clippers                    352        ORG
# 7   4          the Sports Arena            411        FAC
# 8   5          Nomo                        466        ORG
# 9   5          Chavez Ravine               488        PERSON
# 10  5          Dodger                      535        NORP
# 11  6          Scottie Pippen              556        PERSON
# 12  6          Shaq                        568        PERSON
# 13  7          Trekkie                     651        FAC
# 14  7          five                        679        CARDINAL
# 15  7          the L.A. Convention Center  709        FAC
# 16  8          Bud Girls                   720        PERSON
# 17  8          the Olympic Auditorium      777        FAC
# 18  9          Plácido Domingo             794        PERSON
# 19  9          Rossini                     809        PERSON
# 20  9          Dorothy Chandler            833        PERSON
# 21  9          Peter Sellers               906        PERSON
# 22  10         Shrine                      921        ORG
# 23  10         Richard Sakai               955        PERSON
# 24  10         Oscar                       973        PERSON
# 25  10         The Simpsons                1011       WORK_OF_ART
# 26  11         944th                       1048       ORDINAL
# 27  11         Saigon                      1079       PERSON
# 28  11         Beauty                      1107       PERSON
# 29  11         Shubert                     1140       PERSON
# 30  12         Chinese                     1149       NORP
# 31  12         Asian                       1208       NORP
# 32  12         the Bicycle Club            1233       ORG
# 33  13         Hollywood                   1366       GPE
# 34  13         Burbank                     1378       PERSON
# 35  14         Thousands                   1389       CARDINAL
# 36  14         Julio Iglesias              1429       PERSON

# %%
# Save results!
spacy_ner_df.to_excel('data.ner_spacy.xls')

# %% [markdown]
# ### Getting counts from the data
#
# Use `value_counts()` to count the values in any column of a pandas dataframe.
#
# #### Counts for `type`

# %%
# Get the counts for the column 'type'
nltk_ner_df['type'].value_counts()
# Out:
# ORGANIZATION    15
# PERSON          12
# GPE             9
# Name: type, dtype: int64

# %%
# If you have spacy working
#spacy_ner_df['type'].value_counts()

# %%
# We can also convert this data into a dictionary:
type_counts = dict( nltk_ner_df['type'].value_counts() )
type_counts
# Out:
# {'ORGANIZATION': 15, 'PERSON': 12, 'GPE': 9}

# %%
# And we can loop over the (key,value) pairs of any dictionary like this:

for key,value in type_counts.items():
    print(key,':',value)
# Out:
# ORGANIZATION : 15
# PERSON : 12
# GPE : 9

# %% [markdown]
# #### Counts for `entity`

# %%
# Count the number of unique values under entity
nltk_ner_df['entity'].value_counts()
# Out:
# Julio Iglesias            1
# Dodger                    1
# Universal Amphitheater    1
# Shrine                    1
# Simpsons                  1
# Miss Saigon               1
# Richard Sakai             1
# Bud                       1
# Chinese                   1
# Scottie                   1
# Rose                      1
# Clippers                  1
# Ahmanson                  1
# Girls                     1
# Nomo                      1
# Domingo                   1
# Rossini                   1
# Plácido                   1
# USC                       1
# Coliseum                  1
# Trekkie                   1
# Bruin                     1
# L.A. Convention Center    1
# Chavez Ravine             1
# Bicycle Club              1
# Pippen                    1
# Dorothy                   1
# Hollywood                 1
# Beauty                    1
# Asian                     1
# Sports Arena              1
# Shubert                   1
# Burbank                   1
# Trojan                    1
# Shaq                      1
# Peter Sellers             1
# Name: entity, dtype: int64

# %%
# Get these results as a dictionary
entity_counts = dict( results_df['entity'].value_counts() )
entity_counts
# Out:
# {'Sin': 1,
#  'Los Angeles': 1,
#  'Tut': 1,
#  'America': 1,
#  'Hollywood Bowl': 1,
#  'Qris': 1,
#  'Sports Arena': 1,
#  'Asian': 1,
#  'Bud': 1,
#  'Santa Monica': 1,
#  'Universal Studios': 1,
#  'Pippen': 1,
#  'Berry Farm': 1,
#  'Knott': 1,
#  'The Lollapalooza': 1,
#  'Plaza': 1,
#  'Hollywood Park': 1,
#  'L.A. Convention Center': 1,
#  'Ahmanson': 1,
#  'Robert': 1,
#  'Disneyland': 1,
#  'Americans': 1,
#  'Jubilee Choir': 1,
#  'Beauty': 1,
#  'Hollywood Riviera': 1,
#  'César Chávez': 1,
#  'Chicanos': 1,
#  'Rossini': 1,
#  'Domingo': 1,
#  'Bicycle Club': 1,
#  'Pomona Raceway': 1,
#  'Codrescu': 1,
#  'Clippers': 1,
#  'Rose': 1,
#  'USC': 1,
#  'Trojan': 1,
#  'Chinese': 1,
#  'Stomp': 1,
#  'Andrei': 1,
#  'LACMA': 1,
#  'Universal Amphitheater': 1,
#  'Pizzicato': 1,
#  'Plácido': 1,
#  'West Hollywood': 1,
#  'Shrine': 1,
#  'Nomo': 1,
#  'Trekkie': 1,
#  'Burbank': 1,
#  'Volleyball': 1,
#  'Santa Anita Racetrack': 1,
#  'McNeil': 1,
#  'Republican': 1,
#  'Hollywood': 1,
#  'Soleil': 1,
#  'Drag': 1,
#  'Dorothy': 1,
#  'Shaq': 1,
#  'Wadsworth': 1,
#  'Japan': 1,
#  'Bonaventure': 1,
#  'Chavez Ravine': 1,
#  'Endless': 1,
#  'Orange County': 1,
#  'Japanese': 1,
#  'Bruin': 1,
#  'Hilton': 1,
#  'Coliseum': 1,
#  'Central Library': 1,
#  'Greek': 1,
#  'Girls': 1,
#  'Cirque': 1,
#  'MOCA': 1,
#  'Sheraton': 1,
#  'AIDS': 1,
#  'Scottie': 1,
#  'Chris': 1,
#  'Dodger': 1,
#  'John Mauceri': 1,
#  'Shubert': 1,
#  'Malibu': 1,
#  'Magic Mountain': 1,
#  'Richard Sakai': 1,
#  'Miss Saigon': 1,
#  'Simpsons': 1,
#  'Andy Warhol': 1,
#  'Julio Iglesias': 1,
#  'Street': 1,
#  'Peter Sellers': 1}

# %%
# Loop over these results:
for entity,count in entity_count_dict.items():
    print(entity,count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-148-06be9cd68c4a> in <module>
#       1 # Loop over these results:
# ----> 2 for entity,count in entity_count_dict.items():
#       3     print(entity,count)
#
# NameError: name 'entity_count_dict' is not defined

# %% [markdown]
# #### Counts for `entity+type`

# %%
# For both together
results_df.groupby(['entity','type']).size()
# Out:
# entity                  type
# AIDS                    ORGANIZATION    1
# Ahmanson                ORGANIZATION    1
# America                 ORGANIZATION    1
# Americans               ORGANIZATION    1
# Andrei                  PERSON          1
# Andy Warhol             PERSON          1
# Asian                   GPE             1
# Beauty                  PERSON          1
# Berry Farm              PERSON          1
# Bicycle Club            ORGANIZATION    1
# Bonaventure             ORGANIZATION    1
# Bruin                   GPE             1
# Bud                     PERSON          1
# Burbank                 GPE             1
# Central Library         ORGANIZATION    1
# Chavez Ravine           ORGANIZATION    1
# Chicanos                GPE             1
# Chinese                 GPE             1
# Chris                   GPE             1
# Cirque                  GPE             1
# Clippers                ORGANIZATION    1
# Codrescu                ORGANIZATION    1
# Coliseum                GPE             1
# César Chávez            PERSON          1
# Disneyland              GPE             1
# Dodger                  GPE             1
# Domingo                 PERSON          1
# Dorothy                 ORGANIZATION    1
# Drag                    GPE             1
# Endless                 GPE             1
#                                        ..
# Pomona Raceway          ORGANIZATION    1
# Qris                    PERSON          1
# Republican              ORGANIZATION    1
# Richard Sakai           PERSON          1
# Robert                  PERSON          1
# Rose                    ORGANIZATION    1
# Rossini                 PERSON          1
# Santa Anita Racetrack   ORGANIZATION    1
# Santa Monica            ORGANIZATION    1
# Scottie                 PERSON          1
# Shaq                    PERSON          1
# Sheraton                ORGANIZATION    1
# Shrine                  GPE             1
# Shubert                 ORGANIZATION    1
# Simpsons                ORGANIZATION    1
# Sin                     PERSON          1
# Soleil                  PERSON          1
# Sports Arena            ORGANIZATION    1
# Stomp                   PERSON          1
# Street                  GPE             1
# The Lollapalooza        FACILITY        1
# Trekkie                 ORGANIZATION    1
# Trojan                  GPE             1
# Tut                     PERSON          1
# USC                     ORGANIZATION    1
# Universal Amphitheater  ORGANIZATION    1
# Universal Studios       PERSON          1
# Volleyball              GPE             1
# Wadsworth               LOCATION        1
# West Hollywood          LOCATION        1
# Length: 88, dtype: int64

# %%
# Get these results as a dictionary
entity_type_counts = dict( results_df.groupby(['entity','type']).size() )
entity_type_counts
# Out:
# {('AIDS', 'ORGANIZATION'): 1,
#  ('Ahmanson', 'ORGANIZATION'): 1,
#  ('America', 'ORGANIZATION'): 1,
#  ('Americans', 'ORGANIZATION'): 1,
#  ('Andrei', 'PERSON'): 1,
#  ('Andy Warhol', 'PERSON'): 1,
#  ('Asian', 'GPE'): 1,
#  ('Beauty', 'PERSON'): 1,
#  ('Berry Farm', 'PERSON'): 1,
#  ('Bicycle Club', 'ORGANIZATION'): 1,
#  ('Bonaventure', 'ORGANIZATION'): 1,
#  ('Bruin', 'GPE'): 1,
#  ('Bud', 'PERSON'): 1,
#  ('Burbank', 'GPE'): 1,
#  ('Central Library', 'ORGANIZATION'): 1,
#  ('Chavez Ravine', 'ORGANIZATION'): 1,
#  ('Chicanos', 'GPE'): 1,
#  ('Chinese', 'GPE'): 1,
#  ('Chris', 'GPE'): 1,
#  ('Cirque', 'GPE'): 1,
#  ('Clippers', 'ORGANIZATION'): 1,
#  ('Codrescu', 'ORGANIZATION'): 1,
#  ('Coliseum', 'GPE'): 1,
#  ('César Chávez', 'PERSON'): 1,
#  ('Disneyland', 'GPE'): 1,
#  ('Dodger', 'GPE'): 1,
#  ('Domingo', 'PERSON'): 1,
#  ('Dorothy', 'ORGANIZATION'): 1,
#  ('Drag', 'GPE'): 1,
#  ('Endless', 'GPE'): 1,
#  ('Girls', 'PERSON'): 1,
#  ('Greek', 'GPE'): 1,
#  ('Hilton', 'GPE'): 1,
#  ('Hollywood', 'GPE'): 1,
#  ('Hollywood Bowl', 'ORGANIZATION'): 1,
#  ('Hollywood Park', 'FACILITY'): 1,
#  ('Hollywood Riviera', 'ORGANIZATION'): 1,
#  ('Japan', 'GPE'): 1,
#  ('Japanese', 'GPE'): 1,
#  ('John Mauceri', 'PERSON'): 1,
#  ('Jubilee Choir', 'ORGANIZATION'): 1,
#  ('Julio Iglesias', 'PERSON'): 1,
#  ('Knott', 'PERSON'): 1,
#  ('L.A. Convention Center', 'ORGANIZATION'): 1,
#  ('LACMA', 'GPE'): 1,
#  ('Los Angeles', 'GPE'): 1,
#  ('MOCA', 'ORGANIZATION'): 1,
#  ('Magic Mountain', 'PERSON'): 1,
#  ('Malibu', 'GPE'): 1,
#  ('McNeil', 'ORGANIZATION'): 1,
#  ('Miss Saigon', 'ORGANIZATION'): 1,
#  ('Nomo', 'ORGANIZATION'): 1,
#  ('Orange County', 'GPE'): 1,
#  ('Peter Sellers', 'PERSON'): 1,
#  ('Pippen', 'PERSON'): 1,
#  ('Pizzicato', 'ORGANIZATION'): 1,
#  ('Plaza', 'ORGANIZATION'): 1,
#  ('Plácido', 'PERSON'): 1,
#  ('Pomona Raceway', 'ORGANIZATION'): 1,
#  ('Qris', 'PERSON'): 1,
#  ('Republican', 'ORGANIZATION'): 1,
#  ('Richard Sakai', 'PERSON'): 1,
#  ('Robert', 'PERSON'): 1,
#  ('Rose', 'ORGANIZATION'): 1,
#  ('Rossini', 'PERSON'): 1,
#  ('Santa Anita Racetrack', 'ORGANIZATION'): 1,
#  ('Santa Monica', 'ORGANIZATION'): 1,
#  ('Scottie', 'PERSON'): 1,
#  ('Shaq', 'PERSON'): 1,
#  ('Sheraton', 'ORGANIZATION'): 1,
#  ('Shrine', 'GPE'): 1,
#  ('Shubert', 'ORGANIZATION'): 1,
#  ('Simpsons', 'ORGANIZATION'): 1,
#  ('Sin', 'PERSON'): 1,
#  ('Soleil', 'PERSON'): 1,
#  ('Sports Arena', 'ORGANIZATION'): 1,
#  ('Stomp', 'PERSON'): 1,
#  ('Street', 'GPE'): 1,
#  ('The Lollapalooza', 'FACILITY'): 1,
#  ('Trekkie', 'ORGANIZATION'): 1,
#  ('Trojan', 'GPE'): 1,
#  ('Tut', 'PERSON'): 1,
#  ('USC', 'ORGANIZATION'): 1,
#  ('Universal Amphitheater', 'ORGANIZATION'): 1,
#  ('Universal Studios', 'PERSON'): 1,
#  ('Volleyball', 'GPE'): 1,
#  ('Wadsworth', 'LOCATION'): 1,
#  ('West Hollywood', 'LOCATION'): 1}

# %%
# Loop over these results:
for (entity,ent_type),count in entity_type_counts.items():
    print(entity,ent_type,count)
# Out:
# AIDS ORGANIZATION 1
# Ahmanson ORGANIZATION 1
# America ORGANIZATION 1
# Americans ORGANIZATION 1
# Andrei PERSON 1
# Andy Warhol PERSON 1
# Asian GPE 1
# Beauty PERSON 1
# Berry Farm PERSON 1
# Bicycle Club ORGANIZATION 1
# Bonaventure ORGANIZATION 1
# Bruin GPE 1
# Bud PERSON 1
# Burbank GPE 1
# Central Library ORGANIZATION 1
# Chavez Ravine ORGANIZATION 1
# Chicanos GPE 1
# Chinese GPE 1
# Chris GPE 1
# Cirque GPE 1
# Clippers ORGANIZATION 1
# Codrescu ORGANIZATION 1
# Coliseum GPE 1
# César Chávez PERSON 1
# Disneyland GPE 1
# Dodger GPE 1
# Domingo PERSON 1
# Dorothy ORGANIZATION 1
# Drag GPE 1
# Endless GPE 1
# Girls PERSON 1
# Greek GPE 1
# Hilton GPE 1
# Hollywood GPE 1
# Hollywood Bowl ORGANIZATION 1
# Hollywood Park FACILITY 1
# Hollywood Riviera ORGANIZATION 1
# Japan GPE 1
# Japanese GPE 1
# John Mauceri PERSON 1
# Jubilee Choir ORGANIZATION 1
# Julio Iglesias PERSON 1
# Knott PERSON 1
# L.A. Convention Center ORGANIZATION 1
# LACMA GPE 1
# Los Angeles GPE 1
# MOCA ORGANIZATION 1
# Magic Mountain PERSON 1
# Malibu GPE 1
# McNeil ORGANIZATION 1
# Miss Saigon ORGANIZATION 1
# Nomo ORGANIZATION 1
# Orange County GPE 1
# Peter Sellers PERSON 1
# Pippen PERSON 1
# Pizzicato ORGANIZATION 1
# Plaza ORGANIZATION 1
# Plácido PERSON 1
# Pomona Raceway ORGANIZATION 1
# Qris PERSON 1
# Republican ORGANIZATION 1
# Richard Sakai PERSON 1
# Robert PERSON 1
# Rose ORGANIZATION 1
# Rossini PERSON 1
# Santa Anita Racetrack ORGANIZATION 1
# Santa Monica ORGANIZATION 1
# Scottie PERSON 1
# Shaq PERSON 1
# Sheraton ORGANIZATION 1
# Shrine GPE 1
# Shubert ORGANIZATION 1
# Simpsons ORGANIZATION 1
# Sin PERSON 1
# Soleil PERSON 1
# Sports Arena ORGANIZATION 1
# Stomp PERSON 1
# Street GPE 1
# The Lollapalooza FACILITY 1
# Trekkie ORGANIZATION 1
# Trojan GPE 1
# Tut PERSON 1
# USC ORGANIZATION 1
# Universal Amphitheater ORGANIZATION 1
# Universal Studios PERSON 1
# Volleyball GPE 1
# Wadsworth LOCATION 1
# West Hollywood LOCATION 1

# %% [markdown]
# ### Practice

# %%
df_tropic = pd.read_excel('../corpora/tropic_of_orange/metadata.xls')
df_tropic
# Out:
#           fn  part   part_day               part_title  chapter  \
# 0   ch01.txt  1     Monday     Summer Solstice          1
# 1   ch02.txt  1     Monday     Summer Solstice          2
# 2   ch03.txt  1     Monday     Summer Solstice          3
# 3   ch04.txt  1     Monday     Summer Solstice          4
# 4   ch05.txt  1     Monday     Summer Solstice          5
# 5   ch06.txt  1     Monday     Summer Solstice          6
# 6   ch07.txt  1     Monday     Summer Solstice          7
# 7   ch08.txt  2     Tuesday    Diamond Lane             8
# 8   ch09.txt  2     Tuesday    Diamond Lane             9
# 9   ch10.txt  2     Tuesday    Diamond Lane             10
# 10  ch11.txt  2     Tuesday    Diamond Lane             11
# 11  ch12.txt  2     Tuesday    Diamond Lane             12
# 12  ch13.txt  2     Tuesday    Diamond Lane             13
# 13  ch14.txt  2     Tuesday    Diamond Lane             14
# 14  ch15.txt  3     Wednesday  Cultural Diversity       15
# 15  ch16.txt  3     Wednesday  Cultural Diversity       16
# 16  ch17.txt  3     Wednesday  Cultural Diversity       17
# 17  ch18.txt  3     Wednesday  Cultural Diversity       18
# 18  ch19.txt  3     Wednesday  Cultural Diversity       19
# 19  ch20.txt  3     Wednesday  Cultural Diversity       20
# 20  ch21.txt  3     Wednesday  Cultural Diversity       21
# 21  ch22.txt  4     Thursday   The Eternal Buzz         22
# 22  ch23.txt  4     Thursday   The Eternal Buzz         23
# 23  ch24.txt  4     Thursday   The Eternal Buzz         24
# 24  ch25.txt  4     Thursday   The Eternal Buzz         25
# 25  ch26.txt  4     Thursday   The Eternal Buzz         26
# 26  ch27.txt  4     Thursday   The Eternal Buzz         27
# 27  ch28.txt  4     Thursday   The Eternal Buzz         28
# 28  ch29.txt  5     Friday     Artificial Intelligence  29
# 29  ch30.txt  5     Friday     Artificial Intelligence  30
# 30  ch31.txt  5     Friday     Artificial Intelligence  31
# 31  ch32.txt  5     Friday     Artificial Intelligence  32
# 32  ch33.txt  5     Friday     Artificial Intelligence  33
# 33  ch34.txt  5     Friday     Artificial Intelligence  34
# 34  ch35.txt  5     Friday     Artificial Intelligence  35
# 35  ch36.txt  6     Saturday   Queen of Angels          36
# 36  ch37.txt  6     Saturday   Queen of Angels          37
# 37  ch38.txt  6     Saturday   Queen of Angels          38
# 38  ch39.txt  6     Saturday   Queen of Angels          39
# 39  ch40.txt  6     Saturday   Queen of Angels          40
# 40  ch41.txt  6     Saturday   Queen of Angels          41
# 41  ch42.txt  6     Saturday   Queen of Angels          42
# 42  ch43.txt  7     Sunday     Pacific Rim              43
# 43  ch44.txt  7     Sunday     Pacific Rim              44
# 44  ch45.txt  7     Sunday     Pacific Rim              45
# 45  ch46.txt  7     Sunday     Pacific Rim              46
# 46  ch47.txt  7     Sunday     Pacific Rim              47
# 47  ch48.txt  7     Sunday     Pacific Rim              48
# 48  ch49.txt  7     Sunday     Pacific Rim              49
#
#              chapter_title                         setting           narrator
# 0   Midday                  Not Too Far From Mazatlán       Rafaela Cortes
# 1   Benefits                Koreatown                       Bobby Ngu
# 2   Weather Report          Westside                        Emi
# 3   Station ID              Jefferson & Normandie           Buzzworm
# 4   Traffic Window          Harbor Freeway                  Manzanar Murakami
# 5   Coffee Break            Downtown                        Gabriel Balboa
# 6   To Wake                 The Marketplace                 Arcangel
# 7   Rideshare               Downtown Interchange            Manzanar Murakami
# 8   NewsNow                 Hollywood South                 Emi
# 9   Morning                 En México                       Rafaela Cortes
# 10  To Wash                 On the Tropic                   Arcangel
# 11  Car Payment Due         Tijuana via Singapore           Bobby Ngu
# 12  Oldies                  This Old Hood                   Buzzworm
# 13  Budgets                 Skirting Downtown               Gabriel Balboa
# 14  Second Mortgage         Chinatown                       Bobby Ngu
# 15  LA X                    Margarita's Corner              Buzzworm
# 16  The Interview           Manzanar                        Gabriel Balboa
# 17  Daylight                The Cornfield                   Rafaela Cortes
# 18  Hour of the Trucks      The Freeway Canon               Manzanar Murakami
# 19  Disaster Movie Week     Hiro's Sushi                    Emi
# 20  To Eat                  La Cantina de Miseria y Hambre  Arcangel
# 21  You Give Us 22 Minutes  The World                       Buzzworm
# 22  To Labor                East & West Forever             Arcangel
# 23  Dusk                    To the Border                   Rafaela Cortes
# 24  Time & a Half           Limousine Way                   Gabriel Balboa
# 25  Life Insurance          L.A./T.J.                       Bobby Ngu
# 26  Live on Air             El A                            Emi
# 27  Lane Change             Avoiding the Harbor             Manzanar Murakami
# 28  Promos                  World Wide Web                  Emi
# 29  Dawn                    The Other Side                  Rafaela Cortes
# 30  AM/FM                   FreeZone                        Buzzworm
# 31  Overtime                El Zócalo                       Gabriel Balboa
# 32  To Dream                America                         Arcangel
# 33  Visa Card               Final Destination               Bobby Ngu
# 34  Jam                     Greater L.A.                    Manzanar Murakami
# 35  To Perform              Angel's Flight                  Arcangel
# 36  The Car Show            Front Line                      Buzzworm
# 37  Nightfall               Aztlán                          Rafaela Cortes
# 38  Working Weekend         Dirt Shoulder                   Gabriel Balboa
# 39  Social Security         I-5                             Bobby Ngu
# 40  Prime Time              Last Stop                       Emi
# 41  Drive-By                Virtually Everywhere            Manzanar Murakami
# 42  Deadline                Over the Net                    Gabriel Balboa
# 43  Commercial Break        The Big Sleep                   Emi
# 44  Midnight                The Line                        Rafaela Cortes
# 45  SigAlert                The Rim                         Manzanar Murakami
# 46  To Die                  Pacific Rim Auditorium          Arcangel
# 47  Hour 25                 Into the Boxes                  Buzzworm
# 48  American Express        Mi Casa/Su Casa                 Bobby Ngu

# %%
## @TODO:

# make an empty list for all results in the book
all_results = []

# loop over each row...
for index,row in df_tropic.iterrows():
    # values for each row are available as keys on the 'row' dictionary
    fn=row['fn']
    chapter_num=row['chapter']
    
    # no spoilers!
    if chapter_num>35: break
        
    # print filename
    print(fn,'...')

    # get full path
    path=os.path.join('../corpora/tropic_of_orange/texts', fn)
    
    # open text
    with open(path) as file:
        txt=file.read()
        
    # parse NER's
    ner_results_ld = ner_nltk(txt)
    
    # add to all results
    for result_dict in ner_results_ld:
        result_dict['fn']=fn
        all_results.append(result_dict)

# make a data frame
all_results_df=pd.DataFrame(all_results)
# Out:
# ch01.txt ...
# ch02.txt ...
# ch03.txt ...
# ch04.txt ...
# ch05.txt ...
# ch06.txt ...
# ch07.txt ...
# ch08.txt ...
# ch09.txt ...
# ch10.txt ...
# ch11.txt ...
# ch12.txt ...
# ch13.txt ...
# ch14.txt ...
# ch15.txt ...
# ch16.txt ...
# ch17.txt ...
# ch18.txt ...
# ch19.txt ...
# ch20.txt ...
# ch21.txt ...
# ch22.txt ...
# ch23.txt ...
# ch24.txt ...
# ch25.txt ...
# ch26.txt ...
# ch27.txt ...
# ch28.txt ...
# ch29.txt ...
# ch30.txt ...
# ch31.txt ...
# ch32.txt ...
# ch33.txt ...
# ch34.txt ...
# ch35.txt ...
# ch36.txt ...

# %%
all_results_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                _sent  \
# 0     Rafaela Cortes spent the morning barefoot, sweeping both dead and living things from over and under beds, from behind doors and shutters, through archways, along the veranda—sweeping them all across the deep shadows and luminous sunlight carpeting the cool tile floors.
# 1
# 2     Every morning, a small pile of assorted insects and tiny animals—moths and spiders, lizards and beetles
# 3     And the snake that slithered away at the urging of her broom—probably not poisonous, but one never knew.
# 4     Every morning it was the same.
# 5     Every morning, she swept this mound of dead and wiggling things to the door and off the side of the veranda and into the dark green undergrowth with the same flourish.
# 6     Occasionally, there was more of one species or the other, but each somehow always made its way back into the house.
# 7     On some days, it seemed to twirl before her broom communicating a kind of dance that seemed to send a visceral message up the broom to her fingertips.
# 8     It made no difference if she closed the doors and shutters at the first sign of dusk or if she left the house unoccupied and tightly shut for several days.
# 9
# 10
# 11    Every morning when the house was thrown open to the sunlight, she knew that she and the boy had not slept alone that night.
# 12
# 13    Hummingbirds and parakeets fluttered across the rooms, stirring the languid humidity settled by the night, frantically searching for escape through the open lace curtains, while crawling lives hid beneath furniture or presented itself lifeless at her feet.
# 14    When she first came to the house, she couldn't find a broom to accomplish this daily ritual, not to mention for sweeping the clouds of cobwebs from the dark, rough-hewn rafters.
# 15
# 16    Gabriel had left an American vacuum cleaner in a closet—an old steel Electrolux purchased at the Rose Bowl swap meet for thirty dollars.
# 17
# 18
# 19
# 20
# 21    When the electricity wasn't shut off, Rafaela dragged the vacuum
# 22    the hard Bakelite wheels bumping over the clay tiles and the woven throw rugs—from one room to the next but soon depleted Gabriel's supply of vacuum bags.
# 23
# 24
# 25    One day, attempting to use the vacuum cleaner without the bags resulted in jamming the gears with pieces of the crab, not to mention everything else, and that was the end of the Electrolux.
# 26    When Rafaela told Gabriel that the Electrolux had died, there was an uncomfortable silence on the other end of the line, probably because Gabriel had had some idea that a stainless steel vacuum cleaner was something incredibly wise to have in the salty humidity of Mazatlán and also because he had lugged it one thousand miles on one particularly sacrificial trip made in a borrowed Volkswagen van.
# 27
# 28
# 29
# ...  ..
# 3651  all simultaneously—a percussive orchestration that even Manzanar found incredible.
# 3652  And CLICK, one two, SLIDE, three four, FLOMP, one two, BLAM, three four, SNAP, one two VROOOM, three four.
# 3653
# 3654
# 3655
# 3656
# 3657
# 3658
# 3659
# 3660
# 3661
# 3662
# 3663  And then the syncopated REAR VIEW CHECK IT OUT and a one and a two, and AC UP TO THE MAX and a three and a four, and CREEP ON OUT and a five and a six, and MERGE, MERGE, MERGE.
# 3664
# 3665
# 3666
# 3667
# 3668
# 3669
# 3670
# 3671
# 3672  And Manzanar, loathe to lose any moment, writhed with exhilaration and christened it all: the greatest jam session the world had ever known.
# 3673  In moments such as these, the mechanical and the human elements of Manzanar's orchestra became blurred.
# 3674  So when the inevitable impossibility of moving in the greatest traffic jam the world had ever seen made people GROAN one two, UNLATCH DOORS three four, EMERGE five six, Manzanar gripped his baton like a knife.
# 3675
# 3676
# 3677
# 3678
# 3679  He saw them all with their moving mouths speaking out of sync, as in a Toho Film production of Godzilla, with a strange dubbed language not their own.
# 3680
#
#       _sent_num            entity        fn  star_char      type
# 0     1          Rafaela Cortes    ch01.txt  14         PERSON
# 1     1          the morning       ch01.txt  32         TIME
# 2     3          Every morning     ch01.txt  483        TIME
# 3     8          one               ch01.txt  896        CARDINAL
# 4     9          Every morning     ch01.txt  922        TIME
# 5     10         Every morning     ch01.txt  953        TIME
# 6     11         one               ch01.txt  1143       CARDINAL
# 7     15         some days         ch01.txt  1431       DATE
# 8     17         first             ch01.txt  1681       ORDINAL
# 9     17         dusk              ch01.txt  1694       TIME
# 10    17         several days      ch01.txt  1764       DATE
# 11    18         Every morning     ch01.txt  1779       TIME
# 12    18         that night        ch01.txt  1888       TIME
# 13    19         the night         ch01.txt  1995       TIME
# 14    20         first             ch01.txt  2162       ORDINAL
# 15    20         daily             ch01.txt  2232       DATE
# 16    21         Gabriel           ch01.txt  2333       PERSON
# 17    21         American          ch01.txt  2354       NORP
# 18    21         Electrolux        ch01.txt  2405       PERSON
# 19    21         the Rose Bowl     ch01.txt  2432       EVENT
# 20    21         thirty dollars    ch01.txt  2461       MONEY
# 21    22         Rafaela           ch01.txt  2508       PERSON
# 22    24         Bakelite          ch01.txt  2545       PERSON
# 23    24         one               ch01.txt  2614       CARDINAL
# 24    24         Gabriel           ch01.txt  2657       PERSON
# 25    26         One day           ch01.txt  2824       DATE
# 26    27         Rafaela           ch01.txt  3020       PERSON
# 27    27         Gabriel           ch01.txt  3033       PERSON
# 28    27         Electrolux        ch01.txt  3053       PERSON
# 29    27         Gabriel           ch01.txt  3153       PERSON
# ...   ..             ...                ...   ...          ...
# 3651  54         Manzanar          ch35.txt  5167       PERSON
# 3652  55         CLICK             ch35.txt  5195       ORG
# 3653  55         SLIDE             ch35.txt  5211       ORG
# 3654  55         three             ch35.txt  5218       CARDINAL
# 3655  55         one two           ch35.txt  5239       CARDINAL
# 3656  55         BLAM              ch35.txt  5245       ORG
# 3657  55         three four        ch35.txt  5257       CARDINAL
# 3658  55         SNAP              ch35.txt  5263       ORG
# 3659  55         two               ch35.txt  5272       CARDINAL
# 3660  55         VROOOM            ch35.txt  5279       ORG
# 3661  55         three             ch35.txt  5286       CARDINAL
# 3662  55         four              ch35.txt  5291       CARDINAL
# 3663  57         OUT               ch35.txt  5353       ORG
# 3664  57         one               ch35.txt  5363       CARDINAL
# 3665  57         two               ch35.txt  5373       CARDINAL
# 3666  57         AC                ch35.txt  5381       ORG
# 3667  57         three and a four  ch35.txt  5418       CARDINAL
# 3668  57         five              ch35.txt  5447       CARDINAL
# 3669  57         MERGE             ch35.txt  5468       ORG
# 3670  57         MERGE             ch35.txt  5475       ORG
# 3671  57         MERGE             ch35.txt  5482       ORG
# 3672  60         Manzanar          ch35.txt  5687       PERSON
# 3673  62         Manzanar          ch35.txt  6009       PERSON
# 3674  67         GROAN             ch35.txt  6577       ORG
# 3675  67         UNLATCH           ch35.txt  6594       ORG
# 3676  67         three four        ch35.txt  6611       CARDINAL
# 3677  67         five six          ch35.txt  6628       CARDINAL
# 3678  67         Manzanar          ch35.txt  6638       NORP
# 3679  68         Toho Film         ch35.txt  6751       LAW
# 3680  68         Godzilla          ch35.txt  6774       ORG
#
# [3681 rows x 6 columns]

# %%
all_results_df.merge(df_tropic,on='fn')
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                _sent  \
# 0     Rafaela Cortes spent the morning barefoot, sweeping both dead and living things from over and under beds, from behind doors and shutters, through archways, along the veranda—sweeping them all across the deep shadows and luminous sunlight carpeting the cool tile floors.
# 1
# 2     Every morning, a small pile of assorted insects and tiny animals—moths and spiders, lizards and beetles
# 3     And the snake that slithered away at the urging of her broom—probably not poisonous, but one never knew.
# 4     Every morning it was the same.
# 5     Every morning, she swept this mound of dead and wiggling things to the door and off the side of the veranda and into the dark green undergrowth with the same flourish.
# 6     Occasionally, there was more of one species or the other, but each somehow always made its way back into the house.
# 7     On some days, it seemed to twirl before her broom communicating a kind of dance that seemed to send a visceral message up the broom to her fingertips.
# 8     It made no difference if she closed the doors and shutters at the first sign of dusk or if she left the house unoccupied and tightly shut for several days.
# 9
# 10
# 11    Every morning when the house was thrown open to the sunlight, she knew that she and the boy had not slept alone that night.
# 12
# 13    Hummingbirds and parakeets fluttered across the rooms, stirring the languid humidity settled by the night, frantically searching for escape through the open lace curtains, while crawling lives hid beneath furniture or presented itself lifeless at her feet.
# 14    When she first came to the house, she couldn't find a broom to accomplish this daily ritual, not to mention for sweeping the clouds of cobwebs from the dark, rough-hewn rafters.
# 15
# 16    Gabriel had left an American vacuum cleaner in a closet—an old steel Electrolux purchased at the Rose Bowl swap meet for thirty dollars.
# 17
# 18
# 19
# 20
# 21    When the electricity wasn't shut off, Rafaela dragged the vacuum
# 22    the hard Bakelite wheels bumping over the clay tiles and the woven throw rugs—from one room to the next but soon depleted Gabriel's supply of vacuum bags.
# 23
# 24
# 25    One day, attempting to use the vacuum cleaner without the bags resulted in jamming the gears with pieces of the crab, not to mention everything else, and that was the end of the Electrolux.
# 26    When Rafaela told Gabriel that the Electrolux had died, there was an uncomfortable silence on the other end of the line, probably because Gabriel had had some idea that a stainless steel vacuum cleaner was something incredibly wise to have in the salty humidity of Mazatlán and also because he had lugged it one thousand miles on one particularly sacrificial trip made in a borrowed Volkswagen van.
# 27
# 28
# 29
# ...  ..
# 3651  all simultaneously—a percussive orchestration that even Manzanar found incredible.
# 3652  And CLICK, one two, SLIDE, three four, FLOMP, one two, BLAM, three four, SNAP, one two VROOOM, three four.
# 3653
# 3654
# 3655
# 3656
# 3657
# 3658
# 3659
# 3660
# 3661
# 3662
# 3663  And then the syncopated REAR VIEW CHECK IT OUT and a one and a two, and AC UP TO THE MAX and a three and a four, and CREEP ON OUT and a five and a six, and MERGE, MERGE, MERGE.
# 3664
# 3665
# 3666
# 3667
# 3668
# 3669
# 3670
# 3671
# 3672  And Manzanar, loathe to lose any moment, writhed with exhilaration and christened it all: the greatest jam session the world had ever known.
# 3673  In moments such as these, the mechanical and the human elements of Manzanar's orchestra became blurred.
# 3674  So when the inevitable impossibility of moving in the greatest traffic jam the world had ever seen made people GROAN one two, UNLATCH DOORS three four, EMERGE five six, Manzanar gripped his baton like a knife.
# 3675
# 3676
# 3677
# 3678
# 3679  He saw them all with their moving mouths speaking out of sync, as in a Toho Film production of Godzilla, with a strange dubbed language not their own.
# 3680
#
#       _sent_num            entity        fn  star_char      type  part  \
# 0     1          Rafaela Cortes    ch01.txt  14         PERSON    1
# 1     1          the morning       ch01.txt  32         TIME      1
# 2     3          Every morning     ch01.txt  483        TIME      1
# 3     8          one               ch01.txt  896        CARDINAL  1
# 4     9          Every morning     ch01.txt  922        TIME      1
# 5     10         Every morning     ch01.txt  953        TIME      1
# 6     11         one               ch01.txt  1143       CARDINAL  1
# 7     15         some days         ch01.txt  1431       DATE      1
# 8     17         first             ch01.txt  1681       ORDINAL   1
# 9     17         dusk              ch01.txt  1694       TIME      1
# 10    17         several days      ch01.txt  1764       DATE      1
# 11    18         Every morning     ch01.txt  1779       TIME      1
# 12    18         that night        ch01.txt  1888       TIME      1
# 13    19         the night         ch01.txt  1995       TIME      1
# 14    20         first             ch01.txt  2162       ORDINAL   1
# 15    20         daily             ch01.txt  2232       DATE      1
# 16    21         Gabriel           ch01.txt  2333       PERSON    1
# 17    21         American          ch01.txt  2354       NORP      1
# 18    21         Electrolux        ch01.txt  2405       PERSON    1
# 19    21         the Rose Bowl     ch01.txt  2432       EVENT     1
# 20    21         thirty dollars    ch01.txt  2461       MONEY     1
# 21    22         Rafaela           ch01.txt  2508       PERSON    1
# 22    24         Bakelite          ch01.txt  2545       PERSON    1
# 23    24         one               ch01.txt  2614       CARDINAL  1
# 24    24         Gabriel           ch01.txt  2657       PERSON    1
# 25    26         One day           ch01.txt  2824       DATE      1
# 26    27         Rafaela           ch01.txt  3020       PERSON    1
# 27    27         Gabriel           ch01.txt  3033       PERSON    1
# 28    27         Electrolux        ch01.txt  3053       PERSON    1
# 29    27         Gabriel           ch01.txt  3153       PERSON    1
# ...   ..             ...                ...   ...          ...   ..
# 3651  54         Manzanar          ch35.txt  5167       PERSON    5
# 3652  55         CLICK             ch35.txt  5195       ORG       5
# 3653  55         SLIDE             ch35.txt  5211       ORG       5
# 3654  55         three             ch35.txt  5218       CARDINAL  5
# 3655  55         one two           ch35.txt  5239       CARDINAL  5
# 3656  55         BLAM              ch35.txt  5245       ORG       5
# 3657  55         three four        ch35.txt  5257       CARDINAL  5
# 3658  55         SNAP              ch35.txt  5263       ORG       5
# 3659  55         two               ch35.txt  5272       CARDINAL  5
# 3660  55         VROOOM            ch35.txt  5279       ORG       5
# 3661  55         three             ch35.txt  5286       CARDINAL  5
# 3662  55         four              ch35.txt  5291       CARDINAL  5
# 3663  57         OUT               ch35.txt  5353       ORG       5
# 3664  57         one               ch35.txt  5363       CARDINAL  5
# 3665  57         two               ch35.txt  5373       CARDINAL  5
# 3666  57         AC                ch35.txt  5381       ORG       5
# 3667  57         three and a four  ch35.txt  5418       CARDINAL  5
# 3668  57         five              ch35.txt  5447       CARDINAL  5
# 3669  57         MERGE             ch35.txt  5468       ORG       5
# 3670  57         MERGE             ch35.txt  5475       ORG       5
# 3671  57         MERGE             ch35.txt  5482       ORG       5
# 3672  60         Manzanar          ch35.txt  5687       PERSON    5
# 3673  62         Manzanar          ch35.txt  6009       PERSON    5
# 3674  67         GROAN             ch35.txt  6577       ORG       5
# 3675  67         UNLATCH           ch35.txt  6594       ORG       5
# 3676  67         three four        ch35.txt  6611       CARDINAL  5
# 3677  67         five six          ch35.txt  6628       CARDINAL  5
# 3678  67         Manzanar          ch35.txt  6638       NORP      5
# 3679  68         Toho Film         ch35.txt  6751       LAW       5
# 3680  68         Godzilla          ch35.txt  6774       ORG       5
#
#      part_day               part_title  chapter chapter_title  \
# 0     Monday   Summer Solstice          1        Midday
# 1     Monday   Summer Solstice          1        Midday
# 2     Monday   Summer Solstice          1        Midday
# 3     Monday   Summer Solstice          1        Midday
# 4     Monday   Summer Solstice          1        Midday
# 5     Monday   Summer Solstice          1        Midday
# 6     Monday   Summer Solstice          1        Midday
# 7     Monday   Summer Solstice          1        Midday
# 8     Monday   Summer Solstice          1        Midday
# 9     Monday   Summer Solstice          1        Midday
# 10    Monday   Summer Solstice          1        Midday
# 11    Monday   Summer Solstice          1        Midday
# 12    Monday   Summer Solstice          1        Midday
# 13    Monday   Summer Solstice          1        Midday
# 14    Monday   Summer Solstice          1        Midday
# 15    Monday   Summer Solstice          1        Midday
# 16    Monday   Summer Solstice          1        Midday
# 17    Monday   Summer Solstice          1        Midday
# 18    Monday   Summer Solstice          1        Midday
# 19    Monday   Summer Solstice          1        Midday
# 20    Monday   Summer Solstice          1        Midday
# 21    Monday   Summer Solstice          1        Midday
# 22    Monday   Summer Solstice          1        Midday
# 23    Monday   Summer Solstice          1        Midday
# 24    Monday   Summer Solstice          1        Midday
# 25    Monday   Summer Solstice          1        Midday
# 26    Monday   Summer Solstice          1        Midday
# 27    Monday   Summer Solstice          1        Midday
# 28    Monday   Summer Solstice          1        Midday
# 29    Monday   Summer Solstice          1        Midday
# ...      ...               ...         ..           ...
# 3651  Friday   Artificial Intelligence  35       Jam
# 3652  Friday   Artificial Intelligence  35       Jam
# 3653  Friday   Artificial Intelligence  35       Jam
# 3654  Friday   Artificial Intelligence  35       Jam
# 3655  Friday   Artificial Intelligence  35       Jam
# 3656  Friday   Artificial Intelligence  35       Jam
# 3657  Friday   Artificial Intelligence  35       Jam
# 3658  Friday   Artificial Intelligence  35       Jam
# 3659  Friday   Artificial Intelligence  35       Jam
# 3660  Friday   Artificial Intelligence  35       Jam
# 3661  Friday   Artificial Intelligence  35       Jam
# 3662  Friday   Artificial Intelligence  35       Jam
# 3663  Friday   Artificial Intelligence  35       Jam
# 3664  Friday   Artificial Intelligence  35       Jam
# 3665  Friday   Artificial Intelligence  35       Jam
# 3666  Friday   Artificial Intelligence  35       Jam
# 3667  Friday   Artificial Intelligence  35       Jam
# 3668  Friday   Artificial Intelligence  35       Jam
# 3669  Friday   Artificial Intelligence  35       Jam
# 3670  Friday   Artificial Intelligence  35       Jam
# 3671  Friday   Artificial Intelligence  35       Jam
# 3672  Friday   Artificial Intelligence  35       Jam
# 3673  Friday   Artificial Intelligence  35       Jam
# 3674  Friday   Artificial Intelligence  35       Jam
# 3675  Friday   Artificial Intelligence  35       Jam
# 3676  Friday   Artificial Intelligence  35       Jam
# 3677  Friday   Artificial Intelligence  35       Jam
# 3678  Friday   Artificial Intelligence  35       Jam
# 3679  Friday   Artificial Intelligence  35       Jam
# 3680  Friday   Artificial Intelligence  35       Jam
#
#                         setting           narrator
# 0     Not Too Far From Mazatlán  Rafaela Cortes
# 1     Not Too Far From Mazatlán  Rafaela Cortes
# 2     Not Too Far From Mazatlán  Rafaela Cortes
# 3     Not Too Far From Mazatlán  Rafaela Cortes
# 4     Not Too Far From Mazatlán  Rafaela Cortes
# 5     Not Too Far From Mazatlán  Rafaela Cortes
# 6     Not Too Far From Mazatlán  Rafaela Cortes
# 7     Not Too Far From Mazatlán  Rafaela Cortes
# 8     Not Too Far From Mazatlán  Rafaela Cortes
# 9     Not Too Far From Mazatlán  Rafaela Cortes
# 10    Not Too Far From Mazatlán  Rafaela Cortes
# 11    Not Too Far From Mazatlán  Rafaela Cortes
# 12    Not Too Far From Mazatlán  Rafaela Cortes
# 13    Not Too Far From Mazatlán  Rafaela Cortes
# 14    Not Too Far From Mazatlán  Rafaela Cortes
# 15    Not Too Far From Mazatlán  Rafaela Cortes
# 16    Not Too Far From Mazatlán  Rafaela Cortes
# 17    Not Too Far From Mazatlán  Rafaela Cortes
# 18    Not Too Far From Mazatlán  Rafaela Cortes
# 19    Not Too Far From Mazatlán  Rafaela Cortes
# 20    Not Too Far From Mazatlán  Rafaela Cortes
# 21    Not Too Far From Mazatlán  Rafaela Cortes
# 22    Not Too Far From Mazatlán  Rafaela Cortes
# 23    Not Too Far From Mazatlán  Rafaela Cortes
# 24    Not Too Far From Mazatlán  Rafaela Cortes
# 25    Not Too Far From Mazatlán  Rafaela Cortes
# 26    Not Too Far From Mazatlán  Rafaela Cortes
# 27    Not Too Far From Mazatlán  Rafaela Cortes
# 28    Not Too Far From Mazatlán  Rafaela Cortes
# 29    Not Too Far From Mazatlán  Rafaela Cortes
# ...                         ...             ...
# 3651  Greater L.A.               Manzanar Murakami
# 3652  Greater L.A.               Manzanar Murakami
# 3653  Greater L.A.               Manzanar Murakami
# 3654  Greater L.A.               Manzanar Murakami
# 3655  Greater L.A.               Manzanar Murakami
# 3656  Greater L.A.               Manzanar Murakami
# 3657  Greater L.A.               Manzanar Murakami
# 3658  Greater L.A.               Manzanar Murakami
# 3659  Greater L.A.               Manzanar Murakami
# 3660  Greater L.A.               Manzanar Murakami
# 3661  Greater L.A.               Manzanar Murakami
# 3662  Greater L.A.               Manzanar Murakami
# 3663  Greater L.A.               Manzanar Murakami
# 3664  Greater L.A.               Manzanar Murakami
# 3665  Greater L.A.               Manzanar Murakami
# 3666  Greater L.A.               Manzanar Murakami
# 3667  Greater L.A.               Manzanar Murakami
# 3668  Greater L.A.               Manzanar Murakami
# 3669  Greater L.A.               Manzanar Murakami
# 3670  Greater L.A.               Manzanar Murakami
# 3671  Greater L.A.               Manzanar Murakami
# 3672  Greater L.A.               Manzanar Murakami
# 3673  Greater L.A.               Manzanar Murakami
# 3674  Greater L.A.               Manzanar Murakami
# 3675  Greater L.A.               Manzanar Murakami
# 3676  Greater L.A.               Manzanar Murakami
# 3677  Greater L.A.               Manzanar Murakami
# 3678  Greater L.A.               Manzanar Murakami
# 3679  Greater L.A.               Manzanar Murakami
# 3680  Greater L.A.               Manzanar Murakami
#
# [3681 rows x 13 columns]

# %%
all_results_df.entity.value_counts()
# Out:
# Rafaela                                       185
# Bobby                                         154
# Gabriel                                       138
# Buzzworm                                      107
# Sol                                           90
# one                                           77
# Arcangel                                      67
# Emi                                           67
# two                                           53
# Manzanar                                      43
# Doña Maria                                    40
# first                                         38
# today                                         38
# L.A.                                          32
# ”                                             28
# Buzz                                          26
# Chinese                                       24
# Mexican                                       23
# Margarita                                     21
# Singapore                                     21
# NewsNow                                       20
# México                                        20
# Balboa                                        20
# One                                           19
# American                                      19
# Rodriguez                                     19
# three                                         16
# Walkman                                       15
# Two                                           15
# Asian                                         14
#                                               ..
# 8328275                                       1
# Club Alabam                                   1
# Brussels Eureka World's Fair for Invention    1
# Washingtonia                                  1
# seven days                                    1
# four inches                                   1
# Westside                                      1
# the National Guard                            1
# Thailand                                      1
# Air Jordans                                   1
# L.A. Bobby                                    1
# hundreds of dollars                           1
# La Chingada                                   1
# Harvard University                            1
# Five hundred years                            1
# 187                                           1
# Hard Copy                                     1
# CLICK                                         1
# Chupacabra                                    1
# Foz                                           1
# Heard                                         1
# Supervising Agricultural Inspector            1
# Hamms                                         1
# the early seventies                           1
# Comprende                                     1
# DUI                                           1
# Subcommandante Marcos                         1
# Possibly Prozac                               1
# Tiffany                                       1
# Peter Sellers                                 1
# Name: entity, Length: 1494, dtype: int64

# %% [markdown]
# ## How can I get the sentiment of sentences?

# %% [markdown]
# ### (2) textblob (recommended)

# %%
from textblob import TextBlob

def sentiment_analysis_textblob(string):
    # first make a blob
    blob = TextBlob(string)

    # make output dictionary
    output_list = []
    
    # for each sentence
    sent_num=0
    for sent in blob.sentences:
        sent_num+=1
        
        # make an empty results dictionary
        result_dict={}
        result_dict['_sent_num'] = sent_num
        result_dict['_sent'] = str(sent)
        
        result_dict['polarity'] = sent.sentiment.polarity
        result_dict['subjectivity'] = sent.sentiment.subjectivity
        
        output_list.append(result_dict)
    
    return pd.DataFrame(output_list)

# %%
sentiment_analysis_textblob(manzanar)
# Out:
#                                                                                                                                                                                                          _sent  \
# 0   Despite everything, every sports event, concert, and whatnot was happening at the same time.
# 1   L.A.\nmarathoners slouched by the droves across the finish line at the Coliseum.
# 2   At the Rose Bowl: UCLA versus\nUSC; the Bruin mascot had been carried off the field with heat stroke, and the Trojan horse was tied up\nafter throwing its sweaty rider.
# 3   The Clippers were attempting a comeback in overtime at the Sports Arena.
# 4   It was the end of the seventhinning stretch, and Nomo fans at Chavez Ravine hunkered down with their cold\nbeers and Dodger dogs.
# 5   Scottie Pippen fouled Shaq who sank a free throw for the Lakers at the Forum in the\nlast seconds.
# 6   The Trekkie convention warped into five at the L.A. Convention Center.
# 7   Bud Girls paraded\nbetween boxing matches at the Olympic Auditorium.
# 8   Plácido Domingo belted Rossini at the Dorothy Chandler\nunder the improbable abstract/minimal/baroque direction of Peter Sellers.
# 9   At the Shrine, executive\nproducer Richard Sakai accepted an Oscar for the movie version of The Simpsons.
# 10  The helicopter landed for\nthe 944th time on the set of Miss Saigon at the Ahmanson, and Beauty smacked the Beast at the Shubert.
# 11  Chinese housewives went for the big stakes in pai gow in the Asian room at the Bicycle Club.
# 12  Live-laughter\nsitcom audiences and boisterous crowds for the daytime and nighttime talks filled every available studio\nin Hollywood and Burbank.
# 13  Thousands of fans melted away with Julio Iglesias at the Universal Amphitheater.
# 14  Robert McNeil and The Jubilee Choir were jumping gospel at the Greek, and movie music nostalgia brimmed\nfrom the Hollywood Bowl with John Mauceri conducting.
# 15  King Tut had returned to LACMA; Andy Warhol to MOCA.
# 16  The AIDS walk 5/10K run was moving through West Hollywood.
# 17  Andrei Codrescu read from “Zombification” at\nthe Central Library.
# 18  Surfers kicked butt with punks in leather and chains at The Lollapalooza in Orange\nCounty.
# 19  Chicanos marched from the Plaza de la Raza down Whittier to César Chávez in solidarity.
# 20  Volleyball\nteams vied for titles all along the beaches from Malibu to the Hollywood Riviera.
# 21  Street fairs and food\nfairs and farmers’ markets bustled with gawkers in every park and parking lot.
# 22  Endless lines extending\ndown major freeways waited to get into Disneyland, Knott’s Berry Farm, Magic Mountain, Universal Studios,\nand Raging Waters for their half-price specials.
# 23  Drag races were underway, deafening the Pomona Raceway,\nand across the way, a 4-H demonstration of cow milking gathered a crowd at the Los Angeles County Fair.
# 24  Japanese Americans reenacted the historic 1942 relocation of thousands of legal aliens at the Santa Anita\nRacetrack.
# 25  Sin Ying Chang and his wife waited in a line five blocks long for the long-awaited premiere of\na new Spielberg film.
# 26  Political rallies and benefit dinners at one thousand dollars a plate for several\nRepublican presidential candidates clapped themselves toward dessert at the Sheraton, the Hilton, and the\nBonaventure.
# 27  The middle class clamored in malls for summer sales; the poor clamored at swap meets.
# 28  Chris &\nQris inquired at will-call about orchestra seats for Pizzicato 5 at the Japan America Theater.
# 29  Across\ntown, the Cirque du Soleil was back for the umpteenth time at the Big Tent at the Santa Monica pier.
# 30  Meanwhile, Stomp stomped trash cans at the Wadsworth.
# 31  And the horses were running neck and neck at\nHollywood Park.
# 32  .
# 33  .
# 34  .
# 35  Everybody was doing their thing in the greatest leisure world ever devised.
#
#     _sent_num  polarity  subjectivity
# 0   1          0.000000  0.125000
# 1   2          0.000000  0.000000
# 2   3          0.600000  0.950000
# 3   4          0.000000  0.000000
# 4   5         -0.377778  0.644444
# 5   6          0.200000  0.433333
# 6   7         -0.100000  0.100000
# 7   8          0.000000  0.000000
# 8   9          0.000000  0.000000
# 9   10         0.000000  0.000000
# 10  11         0.000000  0.000000
# 11  12         0.000000  0.033333
# 12  13         0.400000  0.650000
# 13  14         0.000000  0.000000
# 14  15         0.000000  0.000000
# 15  16         0.000000  0.000000
# 16  17         0.000000  0.000000
# 17  18         0.000000  0.250000
# 18  19         0.000000  0.000000
# 19  20        -0.155556  0.288889
# 20  21         0.000000  0.000000
# 21  22         0.000000  0.000000
# 22  23         0.056389  0.507778
# 23  24         0.155556  0.379167
# 24  25         0.066667  0.066667
# 25  26         0.043182  0.427273
# 26  27         0.000000  0.050000
# 27  28        -0.200000  0.300000
# 28  29         0.000000  0.000000
# 29  30         0.000000  0.050000
# 30  31         0.000000  0.000000
# 31  32         0.000000  0.000000
# 32  33         0.000000  0.000000
# 33  34         0.000000  0.000000
# 34  35         0.000000  0.000000
# 35  36         1.000000  1.000000
